# %%
# open Pandas
import pandas as pd

# %%
# CSV file open with Pandas
# Checkouts = Library Checkouts
# Review Period: Limited on 5.000.000 Rows due to failed import of all existing 39.1M Rows

Checkouts = pd.read_csv("/home/nasa/Downloads/Checkouts_by_Title.csv", nrows=5000000)

# %%
# Print Checkouts
Checkouts
# Out:
#         UsageClass CheckoutType   MaterialType  CheckoutYear  CheckoutMonth  \
# 0         Physical      Horizon           BOOK          2018              2
# 1          Digital    OverDrive          EBOOK          2018              2
# 2         Physical      Horizon  ER, SOUNDDISC          2018              2
# 3         Physical      Horizon           BOOK          2018              2
# 4         Physical      Horizon           BOOK          2018              2
# ...            ...          ...            ...           ...            ...
# 4999995   Physical      Horizon           BOOK          2020              1
# 4999996   Physical      Horizon           BOOK          2020              1
# 4999997    Digital    OverDrive          EBOOK          2020              1
# 4999998    Digital    OverDrive          EBOOK          2020              1
# 4999999   Physical      Horizon           BOOK          2020              1
#
# ...

# %%
# Info about Data
# Question One: What type of data has the list?
# Answer: 3 x int(Number); 8 x object(Plain Text)
Checkouts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000000 entries, 0 to 4999999
# Data columns (total 11 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   UsageClass       object
#  1   CheckoutType     object
#  2   MaterialType     object
#  3   CheckoutYear     int64
#  4   CheckoutMonth    int64
#  5   Checkouts        int64
#  6   Title            object
#  7   Creator          object
#  8   Subjects         object
#  9   Publisher        object
#  10  PublicationYear  object
# dtypes: int64(3), object(8)
# memory usage: 419.6+ MB

# %%
# Info about Data 2
# Question Two: What is the mean of Checkouts?
# Answer: 3.52 Checkouts in the considered reviewed period of 5.000.000 rows.
Checkouts.describe(include='all')
# Out:
#        UsageClass CheckoutType MaterialType  CheckoutYear  CheckoutMonth  \
# count     5000000      5000000      5000000  5.000000e+06   5.000000e+06
# unique          2            5           55           NaN            NaN
# top      Physical      Horizon         BOOK           NaN            NaN
# freq      3203009      3203009      2325016           NaN            NaN
# mean          NaN          NaN          NaN  2.018584e+03   6.649232e+00
# std           NaN          NaN          NaN  5.563327e-01   3.367098e+00
# min           NaN          NaN          NaN  2.018000e+03   1.000000e+00
# 25%           NaN          NaN          NaN  2.018000e+03   4.000000e+00
# 50%           NaN          NaN          NaN  2.019000e+03   7.000000e+00
# 75%           NaN          NaN          NaN  2.019000e+03   1.000000e+01
# max           NaN          NaN          NaN  2.020000e+03   1.200000e+01
#
#            Checkouts      Title          Creator             Subjects  \
# ...

# %%
# Info about Data 3
# print all lines that contains the string"Drama" in column "Subjects"
Checkouts.query('Subjects == "Drama"')
# Out:
#         UsageClass CheckoutType MaterialType  CheckoutYear  CheckoutMonth  \
# 601        Digital       Hoopla   TELEVISION          2018              2
# 787        Digital       Hoopla   TELEVISION          2018              2
# 2636       Digital       Hoopla        MOVIE          2018              2
# 2660       Digital       Hoopla   TELEVISION          2018              2
# 3155       Digital       Hoopla   TELEVISION          2018              2
# ...            ...          ...          ...           ...            ...
# 4628774   Physical      Horizon         BOOK          2019             12
# 4745221    Digital    OverDrive        VIDEO          2019             12
# 4758151   Physical      Horizon         BOOK          2019             12
# 4841106   Physical      Horizon         BOOK          2020              1
# 4897934   Physical      Horizon         BOOK          2020              1
#
#          Checkouts                                              Title  \
# ...

# %%
# Info about data 4
# Question 4: How often are the items borrowed once, twice etc.?
# Answer: Eg. some items are borrowed 5125 x once.
Checkouts["Checkouts"].value_counts()
# Out:
# 1     5125
# 2     1951
# 3      957
# 4      560
# 5      302
#       ...
# 40       1
# 42       1
# 59       1
# 65       1
# 79       1
# Name: Checkouts, Length: 79, dtype: int64

# %%
# Info about data 5
# List Items borrowed above 10 times!
Checkouts[ Checkouts ["Checkouts"] >= 10 ]
# Out:
#         UsageClass CheckoutType MaterialType  CheckoutYear  CheckoutMonth  \
# 7         Physical      Horizon         BOOK          2018              2
# 9          Digital    OverDrive        EBOOK          2018              2
# 20         Digital    OverDrive    AUDIOBOOK          2018              2
# 30         Digital    OverDrive        EBOOK          2018              2
# 46        Physical      Horizon    VIDEODISC          2018              2
# ...            ...          ...          ...           ...            ...
# 4999973    Digital    OverDrive        EBOOK          2020              1
# 4999977   Physical      Horizon    VIDEODISC          2020              1
# 4999979   Physical      Horizon         BOOK          2020              1
# 4999992   Physical      Horizon         BOOK          2020              1
# 4999993    Digital    OverDrive        EBOOK          2020              1
#
#          Checkouts                                              Title  \
# ...

# %%
# Info about data 6
# Histogramm of all Checkouts with more than 10 checkouts
Checkouts[ Checkouts ["Checkouts"] >= 10 ].hist(bins=5)
# Out:
# array([[<AxesSubplot:title={'center':'CheckoutYear'}>,
#         <AxesSubplot:title={'center':'CheckoutMonth'}>],
#        [<AxesSubplot:title={'center':'Checkouts'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
# Info about data 7
# Show Checkouts Books and E-Books!
Checkouts [(Checkouts ["MaterialType"] == "BOOK")|(Checkouts ["MaterialType"] == "EBOOK")]
# Out:
#         UsageClass CheckoutType MaterialType  CheckoutYear  CheckoutMonth  \
# 0         Physical      Horizon         BOOK          2018              2
# 1          Digital    OverDrive        EBOOK          2018              2
# 3         Physical      Horizon         BOOK          2018              2
# 4         Physical      Horizon         BOOK          2018              2
# 5         Physical      Horizon         BOOK          2018              2
# ...            ...          ...          ...           ...            ...
# 4999995   Physical      Horizon         BOOK          2020              1
# 4999996   Physical      Horizon         BOOK          2020              1
# 4999997    Digital    OverDrive        EBOOK          2020              1
# 4999998    Digital    OverDrive        EBOOK          2020              1
# 4999999   Physical      Horizon         BOOK          2020              1
#
#          Checkouts                                              Title  \
# ...

# %%
# Info about data 8
# List in Columns the Checkouts for Books & EBooks!
Checkouts [(Checkouts ["MaterialType"] == "BOOK")|(Checkouts ["MaterialType"] == "EBOOK")][["MaterialType" , "Checkouts"]]
# Out:
#         MaterialType  Checkouts
# 0               BOOK          4
# 1              EBOOK          6
# 3               BOOK          7
# 4               BOOK          1
# 5               BOOK          1
# ...              ...        ...
# 4999995         BOOK          8
# 4999996         BOOK          1
# 4999997        EBOOK          2
# 4999998        EBOOK          1
# 4999999         BOOK          2
#
# [3543158 rows x 2 columns]

# %%
# Info about data 9
# Show Checkouts from Books and EBooks in a Histogramm
Checkouts [(Checkouts ["MaterialType"] == "BOOK")|(Checkouts ["MaterialType"] == "EBOOK")][["MaterialType" , "Checkouts"]].hist(bins=5)
# Out:
# array([[<AxesSubplot:title={'center':'Checkouts'}>]], dtype=object)

# %%
# Info about data 10
# Show all types of Material!
Checkouts ["MaterialType"].unique()
# Out:
# array(['BOOK', 'EBOOK', 'ER, SOUNDDISC', 'SONG', 'MUSIC', 'AUDIOBOOK',
#        'VIDEODISC', 'SOUNDDISC', 'COMIC', 'MOVIE', 'TELEVISION',
#        'VIDEOREC', 'CR', 'REGPRINT', 'SOUNDCASS', 'SOUNDDISC, VIDEODISC',
#        'SOUNDREC', 'VIDEO', 'ER',
#        'SOUNDCASS, SOUNDDISC, VIDEOCASS, VIDEODISC', 'MAGAZINE',
#        'VIDEOCASS', 'ATLAS', 'ER, VIDEODISC', 'LARGEPRINT',
#        'REGPRINT, SOUNDDISC', 'MAP', 'VISUAL', 'MIXED', 'VIDEOCART',
#        'VIDEOCASS, VIDEODISC', 'MUSICSNDREC', 'NOTATEDMUSIC',
#        'SOUNDDISC, SOUNDREC', 'ER, REGPRINT', 'REGPRINT, VIDEOREC',
#        'ER, NONPROJGRAPH', 'UNSPECIFIED', 'MICROFORM', 'GLOBE',
#        'FLASHCARD, SOUNDDISC', 'KIT', 'ER, PRINT', 'FLASHCARD',
#        'SOUNDDISC, VIDEOCASS', 'SOUNDCASS, SOUNDDISC', 'PICTURE', 'PRINT',
#        'COMPFILE', 'NONPROJGRAPH', 'SLIDE, SOUNDCASS', 'ER, VIDEOREC',
#        'REMOTESEN', 'ER, MAP', 'SOUNDCASS, SOUNDDISC, SOUNDREC'],
#       dtype=object)

# %%
# Import seaborn for using a bar graph
import seaborn as sns

# %%
Meine_Daten = Checkouts [(Checkouts ["MaterialType"] == "BOOK")|(Checkouts ["MaterialType"] == "EBOOK")][["MaterialType" , "Checkouts"]]

# %%
# Info about data 11
# Create a bar graph about : How often are Books and Ebooks borrowed based on the considered dataset?
sns.countplot(data=Meine_Daten, x="MaterialType")
# Out:
# <AxesSubplot:xlabel='MaterialType', ylabel='count'>
